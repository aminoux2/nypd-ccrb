# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns = 30


df= pd.read_csv ("C:/Users/asus/Downloads/CCRB-Complaint-Data_202007261025/allegations.csv")
df
# Out:
#        unique_mos_id first_name last_name command_now  complaint_id  \
# 0              10004   Jonathan      Ruiz     078 PCT         42835
# 1              10007       John     Sears     078 PCT         24601
# 2              10007       John     Sears     078 PCT         24601
# 3              10007       John     Sears     078 PCT         26146
# 4              10009      Noemi    Sierra     078 PCT         40253
# ...              ...        ...       ...         ...           ...
# 33353           9992     Tomasz  Pulawski     078 PCT         35671
# 33354           9992     Tomasz  Pulawski     078 PCT         35671
# 33355           9992     Tomasz  Pulawski     078 PCT         35671
# 33356           9992     Tomasz  Pulawski     078 PCT         35671
# 33357           9992     Tomasz  Pulawski     078 PCT         35671
#
#        month_received  year_received  month_closed  year_closed  \
# 0                   7           2019             5         2020
# ...

# %%
df.columns
# Out:
# Index(['unique_mos_id', 'first_name', 'last_name', 'command_now',
#        'complaint_id', 'month_received', 'year_received', 'month_closed',
#        'year_closed', 'command_at_incident', 'rank_abbrev_incident',
#        'rank_abbrev_now', 'rank_now', 'rank_incident', 'mos_ethnicity',
#        'mos_gender', 'mos_age_incident', 'complainant_ethnicity',
#        'complainant_gender', 'complainant_age_incident', 'fado_type',
#        'allegation', 'precinct', 'contact_reason', 'outcome_description',
#        'board_disposition'],
#       dtype='object')

# %%
df.shape
# Out:
# (33358, 26)

# %%
df.describe()
# Out:
#        unique_mos_id  complaint_id  month_received  year_received  \
# count   33358.000000  33358.000000    33358.000000   33358.000000
# mean    18169.912495  23905.058217        6.323551    2010.726782
# std      9566.316896  11954.434138        3.362951       6.034725
# min         2.000000    517.000000        1.000000    1985.000000
# 25%      9671.000000  13684.750000        3.000000    2007.000000
# 50%     19215.000000  25132.000000        6.000000    2012.000000
# 75%     25412.000000  34252.000000        9.000000    2016.000000
# max     36374.000000  43703.000000       12.000000    2020.000000
#
#        month_closed   year_closed  mos_age_incident  complainant_age_incident  \
# count  33358.000000  33358.000000      33358.000000              28546.000000
# mean       6.470772   2011.525661         32.346873                 32.484201
# std        3.343372      6.085907          6.040944                 28.408963
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33358 entries, 0 to 33357
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   unique_mos_id             33358 non-null  int64
#  1   first_name                33358 non-null  object
#  2   last_name                 33358 non-null  object
#  3   command_now               33358 non-null  object
#  4   complaint_id              33358 non-null  int64
#  5   month_received            33358 non-null  int64
#  6   year_received             33358 non-null  int64
#  7   month_closed              33358 non-null  int64
#  8   year_closed               33358 non-null  int64
#  9   command_at_incident       31814 non-null  object
#  10  rank_abbrev_incident      33358 non-null  object
#  11  rank_abbrev_now           33358 non-null  object
#  12  rank_now                  33358 non-null  object
# ...

# %%
df.groupby(['unique_mos_id','fado_type']).agg(np.mean)
# Out:
#                                   complaint_id  month_received  year_received  \
# unique_mos_id fado_type
# 2             Abuse of Authority  23879.250000        8.000000         2011.0
#               Discourtesy         25652.000000        4.000000         2012.0
#               Offensive Language  25652.000000        4.000000         2012.0
# 5             Abuse of Authority  36234.000000       12.000000         2016.0
#               Discourtesy         32429.000000        4.000000         2015.0
# ...                                        ...             ...            ...
# 36339         Abuse of Authority  30690.000000        5.000000         2014.0
#               Offensive Language  30690.000000        5.000000         2014.0
# 36374         Abuse of Authority  19954.200000        2.600000         2010.0
#               Discourtesy         19732.000000        1.000000         2010.0
#               Force               13417.333333        3.666667         2007.0
#
# ...

# %%
df.loc[df['unique_mos_id'] == 2]
# Out:
#       unique_mos_id first_name last_name command_now  complaint_id  \
# 9958              2     Robert   Bracero     001 DET         18923
# 9959              2     Robert   Bracero     001 DET         20015
# 9960              2     Robert   Bracero     001 DET         24851
# 9961              2     Robert   Bracero     001 DET         25652
# 9962              2     Robert   Bracero     001 DET         25652
# 9963              2     Robert   Bracero     001 DET         25652
# 9964              2     Robert   Bracero     001 DET         28369
# 9965              2     Robert   Bracero     001 DET         29450
# 9966              2     Robert   Bracero     001 DET         18923
# 9967              2     Robert   Bracero     001 DET         24851
#
#       month_received  year_received  month_closed  year_closed  \
# 9958               8           2009             8         2010
# 9959               3           2010             6         2010
# ...

# %%
df.groupby(['precinct']).complaint_id.count()
# Out:
# precinct
# 0.0        21
# 1.0       174
# 5.0       160
# 6.0       175
# 7.0       221
#          ...
# 120.0     844
# 121.0     366
# 122.0     238
# 123.0     112
# 1000.0      3
# Name: complaint_id, Length: 79, dtype: int64

# %%
substans = df.loc[df['board_disposition'] == 'Substantiated (Charges)']

# %%
substans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3796 entries, 1 to 33332
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   unique_mos_id             3796 non-null   int64
#  1   first_name                3796 non-null   object
#  2   last_name                 3796 non-null   object
#  3   command_now               3796 non-null   object
#  4   complaint_id              3796 non-null   int64
#  5   month_received            3796 non-null   int64
#  6   year_received             3796 non-null   int64
#  7   month_closed              3796 non-null   int64
#  8   year_closed               3796 non-null   int64
#  9   command_at_incident       3581 non-null   object
#  10  rank_abbrev_incident      3796 non-null   object
#  11  rank_abbrev_now           3796 non-null   object
#  12  rank_now                  3796 non-null   object
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
sns.barplot(x = df['fado_type'], y = df['mos_age_incident'], hue = df['fado_type'], ci = False)

# %%
df[['final_outcome','subtype']]= df['board_disposition'].str.split(' ',n=1, expand = True)
df
# Out:
#        unique_mos_id first_name last_name command_now  complaint_id  \
# 0              10004   Jonathan      Ruiz     078 PCT         42835
# 1              10007       John     Sears     078 PCT         24601
# 2              10007       John     Sears     078 PCT         24601
# 3              10007       John     Sears     078 PCT         26146
# 4              10009      Noemi    Sierra     078 PCT         40253
# ...              ...        ...       ...         ...           ...
# 33353           9992     Tomasz  Pulawski     078 PCT         35671
# 33354           9992     Tomasz  Pulawski     078 PCT         35671
# 33355           9992     Tomasz  Pulawski     078 PCT         35671
# 33356           9992     Tomasz  Pulawski     078 PCT         35671
# 33357           9992     Tomasz  Pulawski     078 PCT         35671
#
#        month_received  year_received  month_closed  year_closed  \
# 0                   7           2019             5         2020
# ...

# %%
precinct_grp = df.groupby('precinct')
precinct_grp['complaint_id'].count()
# Out:
# precinct
# 0.0        21
# 1.0       174
# 5.0       160
# 6.0       175
# 7.0       221
#          ...
# 120.0     844
# 121.0     366
# 122.0     238
# 123.0     112
# 1000.0      3
# Name: complaint_id, Length: 79, dtype: int64

# %%
precinct_count = precinct_grp['complaint_id'].count() > 1000
precinct_count
# Out:
# precinct
# 0.0       False
# 1.0       False
# 5.0       False
# 6.0       False
# 7.0       False
#           ...
# 120.0     False
# 121.0     False
# 122.0     False
# 123.0     False
# 1000.0    False
# Name: complaint_id, Length: 79, dtype: bool

# %%
precinct_grp = df.groupby('precinct')
# precinct_grp = df.groupby(‘precinct’)[[‘complaint_id’, ‘allegation’,]]
precinct_count = precinct_grp.count()
mask = precinct_count > 500
df2 = precinct_count[mask]
# df2.index
precinct_grp.filter(lambda x: x.complaint_id.count() > 500)
# precinct_grp.groups (edited) 
df2 = precinct_grp.filter(lambda x: x.complaint_id.count() > 500)
df2
# Out:
#        unique_mos_id first_name  last_name command_now  complaint_id  \
# 1              10007       John      Sears     078 PCT         24601
# 2              10007       John      Sears     078 PCT         24601
# 3              10007       John      Sears     078 PCT         26146
# 4              10009      Noemi     Sierra     078 PCT         40253
# 12             10026      Brian  Alexander     079 DET         35092
# ...              ...        ...        ...         ...           ...
# 33316           9856     Daniel      Zollo     077 PCT         20786
# 33317           9856     Daniel      Zollo     077 PCT         20786
# 33318           9856     Daniel      Zollo     077 PCT         20786
# 33319           9856     Daniel      Zollo     077 PCT         20786
# 33320           9856     Daniel      Zollo     077 PCT         23623
#
#        month_received  year_received  month_closed  year_closed  \
# 1                  11           2011             8         2012
# ...

# %%
precinct_grp = df.groupby('precinct')
precinct_count = precinct_grp.count()
mask = precinct_count > 500
df2 = precinct_count[mask]
df2 = precinct_grp.filter(lambda x: x.complaint_id.count() > 500)
df2
# Out:
#        unique_mos_id first_name  last_name command_now  complaint_id  \
# 1              10007       John      Sears     078 PCT         24601
# 2              10007       John      Sears     078 PCT         24601
# 3              10007       John      Sears     078 PCT         26146
# 4              10009      Noemi     Sierra     078 PCT         40253
# 12             10026      Brian  Alexander     079 DET         35092
# ...              ...        ...        ...         ...           ...
# 33316           9856     Daniel      Zollo     077 PCT         20786
# 33317           9856     Daniel      Zollo     077 PCT         20786
# 33318           9856     Daniel      Zollo     077 PCT         20786
# 33319           9856     Daniel      Zollo     077 PCT         20786
# 33320           9856     Daniel      Zollo     077 PCT         23623
#
#        month_received  year_received  month_closed  year_closed  \
# 1                  11           2011             8         2012
# ...

# %%
ax = sns.barplot(x = 'precinct', y = df2['complaint_id'], hue = 'fado_type', data = df2, ci = False)
sns.set(rc={'figure.figsize': (16, 8)})
#how do we get the count on the y axis

# %%
sns.countplot(x='precinct', hue='fado_type', data = df2, order = df2['precinct'].value_counts().index)

sns.set(rc={'figure.figsize': (16, 8)})

# %%
sns.barplot(x = df['precinct'], y = df['mos_age_incident'], hue = df['fado_type'], ci = False)

# %%
df2['precinct'] = df2['precinct'].astype(int)
pgroup = df2.groupby('precinct')
count = pgroup['complaint_id'].count()
mask = count > 1000
over1k = count[mask]
over1k
df2
# Out:
#        unique_mos_id first_name  last_name command_now  complaint_id  \
# 1              10007       John      Sears     078 PCT         24601
# 2              10007       John      Sears     078 PCT         24601
# 3              10007       John      Sears     078 PCT         26146
# 4              10009      Noemi     Sierra     078 PCT         40253
# 12             10026      Brian  Alexander     079 DET         35092
# ...              ...        ...        ...         ...           ...
# 33316           9856     Daniel      Zollo     077 PCT         20786
# 33317           9856     Daniel      Zollo     077 PCT         20786
# 33318           9856     Daniel      Zollo     077 PCT         20786
# 33319           9856     Daniel      Zollo     077 PCT         20786
# 33320           9856     Daniel      Zollo     077 PCT         23623
#
#        month_received  year_received  month_closed  year_closed  \
# 1                  11           2011             8         2012
# ...

# %%
pfcount = df2.groupby(['precinct', 'fado_type'])['complaint_id'].count()
mask2 = pfcount > 500
pf = pfcount[mask2]
pf
# Out:
# precinct  fado_type
# 40.0      Abuse of Authority     577
# 43.0      Abuse of Authority     514
# 44.0      Abuse of Authority     662
# 46.0      Abuse of Authority     729
# 47.0      Abuse of Authority     558
# 67.0      Abuse of Authority     715
# 73.0      Abuse of Authority     797
# 75.0      Abuse of Authority    1362
# 77.0      Abuse of Authority     567
# 79.0      Abuse of Authority     677
# 120.0     Abuse of Authority     533
# Name: complaint_id, dtype: int64

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b666bf274d0a> in <module>
# ----> 1 df.columns
#
# NameError: name 'df' is not defined
